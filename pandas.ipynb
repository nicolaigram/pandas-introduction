# %% [markdown]
# ## Objective
#
# Give a short introduction and example on working with data in Python.
#
# We will import a *.csv file and answer a given data analysis question.
#
# **Loading Data**
#
# **Exploring Data**
#
# **Saving Data**
#
# **Analysing Data**

# %% [markdown]
# ## Prereqiusites
#
# No prior knowledge required, but python experience helps

# %% [markdown]
# ## Pros and Cons compared to working with Excel
#
# **Pros**
# - More flexibility
#     - You can use your python skills
# - Can handle more data
#     - Excel is a graphic application that will struggle with large datasets
# - Linear analysis
#     - Easy to follow
#     - Easy to modify
#
#
# **Cons**
# - Has a learning curve (Many people are already familiar with Excel)

# %% [markdown]
# ## Tools we will be using

# %% [markdown]
# ### Python
#
# Python is a dynamically typed programming language.
#
# - Light syntax (easy to learn, hard to master)
# - Good built-in methods for manipulating data
# - Many data libraries / large community

# %% [markdown]
# ### Jupyter Notebook
#
# Jupyter is an application that can create documents, similar to i.e. Microsoft Word. Documents are very different however.
#
# - Create documents that can run code
# - Easy to share results of analysis

# %% [markdown]
# ### Pandas
#
# Pandas is a python library. Great for working with data.
#
# - Reads data from files (csv, xls etc.)
# - Plots data
# - Filters data
# - Sorts data
# - Modifies data

# %% [markdown]
# ## Installation
#
# **Automatic installation**
#
# 1) Install Anaconda https://www.anaconda.com/products/individual
#
# Anaconda comes with pre-installed tools for data analysis
#
#
# **Manual installation**
#
# 1) Install python https://www.python.org/downloads/
#
#     Note: You might already have it on your computer
#     Check "python --version" in a terminal
#
# 2) Install python libraries using pip
#
#     From a terminal:
#     - pip install jupyterlab
#     - pip install pandas

# %% [markdown]
# ## Example

# %% [markdown]
# ### Loading library and data

# %%
import pandas as pd

# %%
# Creating a DataFrame
# A DataFrame is the main object in the Pandas library

df = pd.read_csv('./ramen-ratings.csv') # Data from https://www.kaggle.com/residentmario/ramen-ratings
df
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2572         5           Vifon
# 2573         4         Wai Wai
# 2574         3         Wai Wai
# 2575         2         Wai Wai
# 2576         1        Westbrae
#
#                                                 Variety Style   Country  \
# 0                             T's Restaurant Tantanmen    Cup     Japan
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan
# 2                         Cup Noodles Chicken Vegetable   Cup       USA
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan
# 4                                       Singapore Curry  Pack     India
# ...                                                 ...   ...       ...
# 2572  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl   Vietnam
# ...

# %% [markdown]
# ### Exploring data

# %%
# List columns
df.columns
# Out:
# Index(['Review #', 'Brand', 'Variety', 'Style', 'Country', 'Stars', 'Top Ten'], dtype='object')

# %%
# See types of data
df.dtypes
# Out:
# Review #      int64
# Brand        object
# Variety      object
# Style        object
# Country      object
# Stars       float64
# Top Ten      object
# dtype: object

# %%
# Describe data
df.describe()
# Out:
#           Review #        Stars
# count  2577.000000  2577.000000
# mean   1289.443927     3.654676
# std     744.569010     1.015331
# min       1.000000     0.000000
# 25%     645.000000     3.250000
# 50%    1289.000000     3.750000
# 75%    1934.000000     4.250000
# max    2580.000000     5.000000

# %%
# Show only one columns
df["Stars"]
# Out:
# 0       3.75
# 1       1.00
# 2       2.25
# 3       2.75
# 4       3.75
#         ...
# 2572    3.50
# 2573    1.00
# 2574    2.00
# 2575    2.00
# 2576    0.50
# Name: Stars, Length: 2577, dtype: float64

# %%
# Show only some columns
df[["Stars", "Style"]]
# Out:
#       Stars Style
# 0      3.75   Cup
# 1      1.00  Pack
# 2      2.25   Cup
# 3      2.75  Pack
# 4      3.75  Pack
# ...     ...   ...
# 2572   3.50  Bowl
# 2573   1.00  Pack
# 2574   2.00  Pack
# 2575   2.00  Pack
# 2576   0.50  Pack
#
# [2577 rows x 2 columns]

# %%
# Filter rows
df.loc[df["Stars"] > 4.5]
# Out:
#       Review #            Brand  \
# 5         2575    Samyang Foods
# 10        2570      Tao Kae Noi
# 11        2569         Yamachan
# 14        2566           Nissin
# 17        2563         Yamachan
# ...        ...              ...
# 2527        50          Indomie
# 2530        47          Indomie
# 2532        45          Indomie
# 2549        28           Nissin
# 2564        13  Sapporo Ichiban
#
#                                                 Variety Style      Country  \
# 5                                Kimchi song Song Ramen  Pack  South Korea
# 10                          Creamy tom Yum Kung Flavour  Pack     Thailand
# 11                              Yokohama Tonkotsu Shoyu  Pack          USA
# 14    Demae Ramen Bar Noodle Aka Tonkotsu Flavour In...  Pack    Hong Kong
# 17                                    Tokyo Shoyu Ramen  Pack          USA
# ...                                                 ...   ...          ...
# ...

# %%
# Filter rows (multiple conditions)
df.loc[(df["Stars"] > 4.5) & (df["Country"] == "Japan")] # OBS: Remember paranthesis around conditions
# Out:
#       Review #            Brand                                  Variety  \
# 27        2553           Nissin       Hakata Ramen Noodle White Tonkotsu
# 47        2532           Nissin                    Nippon Onomichi Ramen
# 57        2522         Takamori         Hearty Japanese Style Curry Udon
# 104       2475         Maruchan              Seimen Red Spicy Dandan Men
# 137       2441          MyKuali       Penang Hokkien Prawn Flavor Noodle
# ...        ...              ...                                      ...
# 2397       180            Myojo        Hyobanya No Yakisoba Sauce Flavor
# 2430       147          Higashi                       Nagasaki Sara Udon
# 2453       124           Nissin  Yakisoba With Mayonnaise/Mustard Packet
# 2549        28           Nissin                             Chikin Ramen
# 2564        13  Sapporo Ichiban                                Chow Mein
#
#      Style Country  Stars  Top Ten
# 27    Bowl   Japan   4.75      NaN
# ...

# %%
# Filter by chicken
df.loc[df["Variety"] == "Chicken"] # Problem: Only has exact matches
# Out:
#       Review #        Brand  Variety Style      Country  Stars Top Ten
# 1777       800  Mr. Noodles  Chicken  Pack       Canada   3.00     NaN
# 1807       770        Kailo  Chicken  Pack    Hong Kong   3.50     NaN
# 1905       672     Mug Shot  Chicken  Pack           UK   3.00     NaN
# 2036       541      Yum Yum  Chicken  Pack     Thailand   3.50     NaN
# 2108       469        Gefen  Chicken  Pack          USA   3.50     NaN
# 2133       444     Mr. Udon  Chicken  Pack  South Korea   3.25     NaN
# 2524        53      Indomie  Chicken   Cup    Indonesia   2.00     NaN

# %%
# Filter by chicken (using Python)
df.loc[df["Variety"].str.lower().str.contains("chicken")] # Solution: Use python to match all cases of chicken
# Out:
#       Review #        Brand  \
# 2         2578       Nissin
# 35        2544       Lipton
# 38        2541       Nissin
# 44        2535       Nissin
# 51        2528        Prima
# ...        ...          ...
# 2530        47      Indomie
# 2533        44      Indomie
# 2535        42      Ve Wong
# 2554        23       Nissin
# 2566        11  Six Fortune
#
#                                                 Variety Style      Country  \
# 2                         Cup Noodles Chicken Vegetable   Cup          USA
# 35    Cup-A-Soup Chicken Noodle With White Meat Inst...   Box          USA
# 38    Cup Noodles Very Veggie Spicy Chicken Flavor R...   Cup          USA
# 44    Cup Noodles Very Veggie Chicken Flavor Ramen N...   Cup          USA
# 51    Juzz's Mee Creamy Chicken Flavour (Export Vers...  Pack    Singapore
# ...                                                 ...   ...          ...
# 2530                   Mi Goreng Jumbo Barbecue Chicken  Pack    Indonesia
# ...

# %%
# Plot Stars (rating)
df.plot.hist(y="Stars")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# Sort by highest rating and show top 5
df.sort_values(by="Stars").tail(5)
# Out:
#       Review #    Brand                            Variety Style    Country  \
# 346       2232   Nissin               Spicy Chikin Donburi  Bowl      Japan
# 1837       740  Indomie             Mi Goreng Sate (Local)  Pack  Indonesia
# 350       2228   Nissin                   Raoh Shoyu Ramen  Bowl      Japan
# 800       1778      JML           Spicy King Spicy Chicken  Pack      China
# 667       1911   Nissin  Emergency Chikin Ramen Cup Noodle   Cup      Japan
#
#       Stars Top Ten
# 346     5.0     NaN
# 1837    5.0     NaN
# 350     5.0     NaN
# 800     5.0     NaN
# 667     5.0     NaN

# %%
# Look at single column
df.groupby("Style").size()
# Out:
# Style
# Bar        1
# Bowl     481
# Box        6
# Can        1
# Cup      450
# Pack    1528
# Tray     108
# dtype: int64

# %%
# Plot single column
df.groupby("Style").size().plot.bar()
# Out:
# <AxesSubplot:xlabel='Style'>

# %% [markdown]
# ## Saving data

# %%
# Saving a dataframe
df.head(5).to_csv("first5rows.csv")

# %%
# Saving a plot
df.plot.hist(y="Stars").get_figure().savefig("ratings.png")

# %% [markdown]
# ## Analysing data

# %% [markdown]
# Which Style of ramen scores the highest?

# %%
# Get the average (mean) of each Style of ramen
style = df.groupby("Style").mean().sort_values(by="Stars")[["Stars"]]                                            
style
# Out:
#           Stars
# Style
# Cup    3.498500
# Can    3.500000
# Tray   3.545139
# Bowl   3.670686
# Pack   3.700458
# Box    4.291667
# Bar    5.000000

# %%
style.plot.bar()
# Out:
# <AxesSubplot:xlabel='Style'>

# %%
# Expose noise from low amount of ratings
style["Count"] = df.groupby("Style").size()   # Add new column Count
style.sort_values(by="Count")                 # Print sorted by Count
# Out:
#           Stars  Count
# Style
# Can    3.500000      1
# Bar    5.000000      1
# Box    4.291667      6
# Tray   3.545139    108
# Cup    3.498500    450
# Bowl   3.670686    481
# Pack   3.700458   1528

# %%
# New plot without noise
style.loc[style["Count"] >= 50].plot.bar(y="Stars")
# Out:
# <AxesSubplot:xlabel='Style'>
